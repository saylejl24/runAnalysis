# %%
import pandas as pd
df = pd.read_csv('data/ActivitiesGarmin.csv')
#df = pd.read_csv('NickActivities.csv')
df.info()
df['Activity Type'].describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 807 entries, 0 to 806
# Data columns (total 33 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Activity Type             807 non-null    object
#  1   Date                      807 non-null    object
#  2   Favorite                  807 non-null    bool
#  3   Title                     807 non-null    object
#  4   Distance                  807 non-null    float64
#  5   Calories                  807 non-null    object
#  6   Time                      807 non-null    object
#  7   Avg HR                    807 non-null    object
#  8   Max HR                    807 non-null    object
#  9   Aerobic TE                807 non-null    object
#  10  Avg Run Cadence           807 non-null    int64
#  11  Max Run Cadence           807 non-null    int64
#  12  Avg Pace                  807 non-null    object
#  13  Best Pace                 807 non-null    object
#  14  Total Ascent              807 non-null    object
#  15  Total Descent             807 non-null    object
#  16  Avg Stride Length         807 non-null    float64
#  17  Avg Vertical Ratio        807 non-null    int64
#  18  Avg Vertical Oscillation  807 non-null    int64
#  19  Training Stress Score®    807 non-null    int64
#  20  Grit                      807 non-null    int64
#  21  Flow                      807 non-null    int64
#  22  Dive Time                 807 non-null    object
#  23  Min Temp                  807 non-null    int64
#  24  Surface Interval          807 non-null    object
#  25  Decompression             807 non-null    object
#  26  Best Lap Time             807 non-null    object
#  27  Number of Laps            807 non-null    int64
#  28  Max Temp                  807 non-null    int64
#  29  Moving Time               807 non-null    object
#  30  Elapsed Time              807 non-null    object
#  31  Min Elevation             807 non-null    object
#  32  Max Elevation             807 non-null    object
# dtypes: bool(1), float64(2), int64(10), object(20)
# memory usage: 202.7+ KB
# count         807
# unique          3
# top       Running
# freq          797
# Name: Activity Type, dtype: object

# %%
df = df[['Date', 'Distance','Calories','Avg HR','Avg Run Cadence', 'Avg Pace', 'Best Pace', 
         'Avg Stride Length', 'Elapsed Time']]
df['Date'].describe()
df
# Out:
#                 Date  Distance Calories Avg HR  Avg Run Cadence Avg Pace  \
# 0     11/7/2021 9:13      7.48      744    155              164     8:07
# 1     11/6/2021 9:12      4.03      403    157              165     7:32
# 2    11/5/2021 15:09      4.01      371    155              163     7:16
# 3    11/4/2021 15:35      4.89      497     --              164     7:18
# 4    11/3/2021 16:24      5.30      511    163              164     7:07
# ..               ...       ...      ...    ...              ...      ...
# 802  7/16/2019 11:19      5.63      518    166              148     8:47
# 803   7/12/2019 9:29      6.04      556    166              150     8:43
# 804   7/10/2019 9:23      5.03      427    177              150     7:56
# 805   7/9/2019 14:19      2.52      167    146              148     7:50
# 806   1/1/2017 22:31      6.05      568    162              156     7:29
#
#     Best Pace  Avg Stride Length Elapsed Time
# 0        6:58               1.21      1:09:15
# 1        6:38               1.29      0:30:36
# 2        4:16               1.36      0:41:23
# 3        6:24               1.35      0:38:05
# 4        6:31               1.38      0:40:41
# ..        ...                ...          ...
# 802      6:45               1.24      1:25:29
# 803      3:10               1.23      0:52:42
# 804      7:09               1.35      0:39:53
# 805      6:15               1.40      0:19:46
# 806      1:34               1.37      0:48:20
#
# [807 rows x 9 columns]

# %%
#convert 'Date', 'Avg Pace', 'Best Pace', 'Elapsed Time' objects to datetime format
df['Date'] = pd.to_datetime(df['Date'])
df['Avg Pace'] = pd.to_datetime(df['Avg Pace'], format='%M:%S', errors = 'coerce')
df['Best Pace'] = pd.to_datetime(df['Best Pace'], format='%M:%S', errors = 'coerce')
df['Elapsed Time'] = pd.to_datetime(df['Elapsed Time'], errors = 'coerce')
df.dropna()
# Out:
#                    Date  Distance Calories Avg HR  Avg Run Cadence  \
# 0   2021-11-07 09:13:00      7.48      744    155              164
# 1   2021-11-06 09:12:00      4.03      403    157              165
# 2   2021-11-05 15:09:00      4.01      371    155              163
# 3   2021-11-04 15:35:00      4.89      497     --              164
# 4   2021-11-03 16:24:00      5.30      511    163              164
# ..                  ...       ...      ...    ...              ...
# 802 2019-07-16 11:19:00      5.63      518    166              148
# 803 2019-07-12 09:29:00      6.04      556    166              150
# 804 2019-07-10 09:23:00      5.03      427    177              150
# 805 2019-07-09 14:19:00      2.52      167    146              148
# 806 2017-01-01 22:31:00      6.05      568    162              156
#
#                Avg Pace           Best Pace  Avg Stride Length  \
# 0   1900-01-01 00:08:07 1900-01-01 00:06:58               1.21
# 1   1900-01-01 00:07:32 1900-01-01 00:06:38               1.29
# 2   1900-01-01 00:07:16 1900-01-01 00:04:16               1.36
# 3   1900-01-01 00:07:18 1900-01-01 00:06:24               1.35
# 4   1900-01-01 00:07:07 1900-01-01 00:06:31               1.38
# ..                  ...                 ...                ...
# 802 1900-01-01 00:08:47 1900-01-01 00:06:45               1.24
# 803 1900-01-01 00:08:43 1900-01-01 00:03:10               1.23
# 804 1900-01-01 00:07:56 1900-01-01 00:07:09               1.35
# 805 1900-01-01 00:07:50 1900-01-01 00:06:15               1.40
# 806 1900-01-01 00:07:29 1900-01-01 00:01:34               1.37
#
#            Elapsed Time
# 0   2022-02-07 01:09:15
# 1   2022-02-07 00:30:36
# 2   2022-02-07 00:41:23
# 3   2022-02-07 00:38:05
# 4   2022-02-07 00:40:41
# ..                  ...
# 802 2022-02-07 01:25:29
# 803 2022-02-07 00:52:42
# 804 2022-02-07 00:39:53
# 805 2022-02-07 00:19:46
# 806 2022-02-07 00:48:20
#
# [795 rows x 9 columns]

# %%
#convert 'Avg Pace', 'Best Pace', 'Elapced Time' objects to the number of minutes
df['Avg Pace'] = df['Avg Pace'].dt.hour*60 + df['Avg Pace'].dt.minute + df['Avg Pace'].dt.second/60
df['Best Pace'] = df['Best Pace'].dt.hour*60 + df['Best Pace'].dt.minute + df['Best Pace'].dt.second/60
df['Elapsed Time'] = df['Elapsed Time'].dt.hour*60 + df['Elapsed Time'].dt.minute + df['Elapsed Time'].dt.second/60

# %%
#add 'Avg Speed' and 'Best Speed' columns
df['Avg Speed'] = 60 / df['Avg Pace']
df['Best Speed'] = 60 / df['Best Pace']
df
# Out:
#                    Date  Distance Calories Avg HR  Avg Run Cadence  Avg Pace  \
# 0   2021-11-07 09:13:00      7.48      744    155              164  8.116667
# 1   2021-11-06 09:12:00      4.03      403    157              165  7.533333
# 2   2021-11-05 15:09:00      4.01      371    155              163  7.266667
# 3   2021-11-04 15:35:00      4.89      497     --              164  7.300000
# 4   2021-11-03 16:24:00      5.30      511    163              164  7.116667
# ..                  ...       ...      ...    ...              ...       ...
# 802 2019-07-16 11:19:00      5.63      518    166              148  8.783333
# 803 2019-07-12 09:29:00      6.04      556    166              150  8.716667
# 804 2019-07-10 09:23:00      5.03      427    177              150  7.933333
# 805 2019-07-09 14:19:00      2.52      167    146              148  7.833333
# 806 2017-01-01 22:31:00      6.05      568    162              156  7.483333
#
#      Best Pace  Avg Stride Length  Elapsed Time  Avg Speed  Best Speed
# 0     6.966667               1.21     69.250000   7.392197    8.612440
# 1     6.633333               1.29     30.600000   7.964602    9.045226
# 2     4.266667               1.36     41.383333   8.256881   14.062500
# 3     6.400000               1.35     38.083333   8.219178    9.375000
# 4     6.516667               1.38     40.683333   8.430913    9.207161
# ..         ...                ...           ...        ...         ...
# 802   6.750000               1.24     85.483333   6.831120    8.888889
# 803   3.166667               1.23     52.700000   6.883365   18.947368
# 804   7.150000               1.35     39.883333   7.563025    8.391608
# 805   6.250000               1.40     19.766667   7.659574    9.600000
# 806   1.566667               1.37     48.333333   8.017817   38.297872
#
# [807 rows x 11 columns]

# %%
import numpy as np
df.replace({'--':np.nan},  inplace=True)
df.dropna()
# Out:
#                    Date  Distance Calories Avg HR  Avg Run Cadence  Avg Pace  \
# 0   2021-11-07 09:13:00      7.48      744    155              164  8.116667
# 1   2021-11-06 09:12:00      4.03      403    157              165  7.533333
# 2   2021-11-05 15:09:00      4.01      371    155              163  7.266667
# 4   2021-11-03 16:24:00      5.30      511    163              164  7.116667
# 5   2021-11-01 16:33:00      5.31      522    170              165  7.116667
# ..                  ...       ...      ...    ...              ...       ...
# 802 2019-07-16 11:19:00      5.63      518    166              148  8.783333
# 803 2019-07-12 09:29:00      6.04      556    166              150  8.716667
# 804 2019-07-10 09:23:00      5.03      427    177              150  7.933333
# 805 2019-07-09 14:19:00      2.52      167    146              148  7.833333
# 806 2017-01-01 22:31:00      6.05      568    162              156  7.483333
#
#      Best Pace  Avg Stride Length  Elapsed Time  Avg Speed  Best Speed
# 0     6.966667               1.21     69.250000   7.392197    8.612440
# 1     6.633333               1.29     30.600000   7.964602    9.045226
# 2     4.266667               1.36     41.383333   8.256881   14.062500
# 4     6.516667               1.38     40.683333   8.430913    9.207161
# 5     4.233333               1.38     49.466667   8.430913   14.173228
# ..         ...                ...           ...        ...         ...
# 802   6.750000               1.24     85.483333   6.831120    8.888889
# 803   3.166667               1.23     52.700000   6.883365   18.947368
# 804   7.150000               1.35     39.883333   7.563025    8.391608
# 805   6.250000               1.40     19.766667   7.659574    9.600000
# 806   1.566667               1.37     48.333333   8.017817   38.297872
#
# [784 rows x 11 columns]

# %%
df.replace(',','', regex=True, inplace=True) # remove the commas from the data set

#convert remaining columns of object type to float64
s = df.select_dtypes(include='object').columns

df[s] = df[s].astype("float")

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 807 entries, 0 to 806
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Date               807 non-null    datetime64[ns]
#  1   Distance           807 non-null    float64
#  2   Calories           807 non-null    float64
#  3   Avg HR             796 non-null    float64
#  4   Avg Run Cadence    807 non-null    int64
#  5   Avg Pace           795 non-null    float64
#  6   Best Pace          806 non-null    float64
#  7   Avg Stride Length  807 non-null    float64
#  8   Elapsed Time       807 non-null    float64
#  9   Avg Speed          795 non-null    float64
#  10  Best Speed         806 non-null    float64
# dtypes: datetime64[ns](1), float64(9), int64(1)
# memory usage: 69.5 KB

# %%
df[df.isin(['--']).any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [Date, Distance, Calories, Avg HR, Avg Run Cadence, Avg Pace, Best Pace, Avg Stride Length, Elapsed Time, Avg Speed, Best Speed]
# Index: []

# %%
# remove outliers
from scipy import stats

flo = df.select_dtypes(include='float').columns

for col in flo:
    q_low = df[col].quantile(0.01)
    q_hi  = df[col].quantile(0.99)
    df = df[(df[col] < q_hi) & (df[col] > q_low)]

df = df[~(df['Date'] < '2019-01-01')]
    
df
# Out:
#                    Date  Distance  Calories  Avg HR  Avg Run Cadence  \
# 0   2021-11-07 09:13:00      7.48     744.0   155.0              164
# 1   2021-11-06 09:12:00      4.03     403.0   157.0              165
# 2   2021-11-05 15:09:00      4.01     371.0   155.0              163
# 4   2021-11-03 16:24:00      5.30     511.0   163.0              164
# 5   2021-11-01 16:33:00      5.31     522.0   170.0              165
# ..                  ...       ...       ...     ...              ...
# 798 2019-07-30 12:02:00      4.81     449.0   167.0              148
# 801 2019-07-19 09:39:00      4.03     390.0   167.0              150
# 802 2019-07-16 11:19:00      5.63     518.0   166.0              148
# 803 2019-07-12 09:29:00      6.04     556.0   166.0              150
# 805 2019-07-09 14:19:00      2.52     167.0   146.0              148
#
#      Avg Pace  Best Pace  Avg Stride Length  Elapsed Time  Avg Speed  \
# 0    8.116667   6.966667               1.21     69.250000   7.392197
# 1    7.533333   6.633333               1.29     30.600000   7.964602
# 2    7.266667   4.266667               1.36     41.383333   8.256881
# 4    7.116667   6.516667               1.38     40.683333   8.430913
# 5    7.116667   4.233333               1.38     49.466667   8.430913
# ..        ...        ...                ...           ...        ...
# 798  8.700000   5.200000               1.24     51.750000   6.896552
# 801  9.016667   1.033333               1.19     36.333333   6.654344
# 802  8.783333   6.750000               1.24     85.483333   6.831120
# 803  8.716667   3.166667               1.23     52.700000   6.883365
# 805  7.833333   6.250000               1.40     19.766667   7.659574
#
#      Best Speed
# 0      8.612440
# 1      9.045226
# 2     14.062500
# 4      9.207161
# 5     14.173228
# ..          ...
# 798   11.538462
# 801   58.064516
# 802    8.888889
# 803   18.947368
# 805    9.600000
#
# [646 rows x 11 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(14,6))
sns.histplot(data = df, x='Avg HR').set(title = 'Average HR Distribution')
# Out:
# [Text(0.5, 1.0, 'Average HR Distribution')]

# %%
sns.jointplot(x='Avg Speed',y='Avg Run Cadence', data=df.dropna(),kind='scatter')
print("Correlation coefficient between cadence and speed:", df['Avg Speed'].corr(df['Avg Run Cadence']))
# Out:
# Correlation coefficient between cadence and speed: 0.4141784575616122

# %%
sns.jointplot(x='Avg Speed',y='Avg Stride Length', data=df.dropna(),kind='scatter')
print("Correlation coefficient between stride length and speed:", df['Avg Speed'].corr(df['Avg Stride Length']))
# Out:
# Correlation coefficient between stride length and speed: 0.8494485339487079

# %%
sns.jointplot(x='Avg Run Cadence',y='Avg Stride Length', data=df.dropna(),kind='scatter')
print("Correlation coefficient between stride length and run cadence:", 
      df['Avg Run Cadence'].corr(df['Avg Stride Length'].dropna()))
# Out:
# Correlation coefficient between stride length and run cadence: -0.11298657621197644

# %%
plt.figure(figsize=(14,6))
#add extra column with month for every running session
#df['Month'] = df['Date'].dt.strftime('%b') + " " + df['Date'].dt.strftime('%Y') 
df['Month'] = df['Date'].dt.strftime('%b')
#sort datataset by date in ascending order
df.sort_values(by='Date', inplace=True)
#plot boxplots grouped by month
sns.boxplot(x='Month',y='Avg Speed', palette=["m", "g"], data=df.dropna()).set(title = 'Avg Speed by Month')
# Out:
# [Text(0.5, 1.0, 'Avg Speed by Month')]

# %%
plt.figure(figsize=(14,6))
sns.boxplot(x='Month',y='Avg Run Cadence', palette=["m", "g"], data=df.dropna()).set(title = 'Avg Run Cadence by Month')
# Out:
# [Text(0.5, 1.0, 'Avg Run Cadence by Month')]

# %%
plt.figure(figsize=(14,6))
sns.boxplot(x='Month',y='Avg Stride Length', palette=["m", "g"], data=df.dropna()).set(title = 'Avg Stride Length by Month')
# Out:
# [Text(0.5, 1.0, 'Avg Stride Length by Month')]

# %%
df['Count'] = 1
#aggregate data by week
dfW = df.groupby(pd.Grouper(key='Date',freq='W')).agg({'Count':'sum','Distance':'sum',
'Calories':'sum','Avg HR':'mean','Avg Run Cadence':'mean', 'Avg Speed':'mean','Best Speed':'mean', 
'Avg Pace':'mean', 'Best Pace':'mean', 'Avg Stride Length':'mean', 'Elapsed Time':'mean'}).reset_index()


dfW.dropna()
# Out:
#           Date  Count  Distance  Calories      Avg HR  Avg Run Cadence  \
# 0   2019-07-14      2      8.56     723.0  156.000000       149.000000
# 1   2019-07-21      2      9.66     908.0  166.500000       149.000000
# 3   2019-08-04      3     18.83    1701.0  169.000000       148.000000
# 4   2019-08-11      2     12.00     946.0  145.500000       148.000000
# 5   2019-08-18      3     13.98    1308.0  166.000000       147.333333
# ..         ...    ...       ...       ...         ...              ...
# 117 2021-10-10      9     34.82    3324.0  154.666667       156.444444
# 118 2021-10-17      8     36.84    3472.0  148.875000       161.000000
# 119 2021-10-24      9     33.49    3219.0  147.000000       159.777778
# 120 2021-10-31      1      3.01     289.0  156.000000       164.000000
# 121 2021-11-07      5     26.13    2551.0  160.000000       164.200000
#
#      Avg Speed  Best Speed  Avg Pace  Best Pace  Avg Stride Length  \
# 0     7.271470   14.273684  8.275000   4.708333           1.315000
# 1     6.742732   33.476703  8.900000   3.891667           1.215000
# 3     7.162197   13.210886  8.383333   4.583333           1.293333
# 4     7.248059   11.998434  8.325000   5.108333           1.315000
# 5     7.313905   10.234672  8.250000   5.972222           1.333333
# ..         ...         ...       ...        ...                ...
# 117   7.727592   10.675036  7.825926   6.001852           1.331111
# 118   7.722860   11.000952  7.781250   5.877083           1.287500
# 119   7.608914    9.524527  7.925926   6.546296           1.283333
# 120   8.181818    9.137056  7.333333   6.566667           1.340000
# 121   8.095101   11.020111  7.430000   5.723333           1.324000
#
#      Elapsed Time
# 0       36.233333
# 1       60.908333
# 3       59.383333
# 4       51.275000
# 5       38.566667
# ..            ...
# 117     38.270370
# 118     47.058333
# 119     34.966667
# 120     23.800000
# 121     46.276667
#
# [106 rows x 12 columns]

# %%
# create figure and axis objects with subplots()
fig,ax = plt.subplots(figsize=(14,6))
# make a barplot
#count = ax.bar(dfW['Date'], dfW['Count'],width=10, color='red',label='Number of Runs')
count = ax.bar(dfW['Date'], dfW['Distance'],width=10, color='red',label='Distance per week')
#ax.bar_label(count)
# set x-axis label
ax.set_xlabel('Date')
ax.legend(loc=2)
# set y-axis label
#ax.set_ylabel('Number of Runs',color='red')
ax.set_ylabel('Distance per week',color='red')
# twin object for two different y-axis on the sample plot
ax2=ax.twinx()
# make a plot with different y-axis using second axis object
ax2.plot(dfW['Date'],dfW['Avg Speed'],color='blue',marker='o',label='Average Speed')
ax2.set_ylabel('Average Speed',color='blue')
ax2.legend()
plt.show()

# %%
# create figure and axis objects with subplots()
fig,ax = plt.subplots(figsize=(14,6))
# make a barplot
#count = ax.bar(dfW['Date'], dfW['Count'],width=10, color='red',label='Number of Runs')
count = ax.bar(dfW['Date'], dfW['Distance'],width=10, color='red',label='Distance per week')
#ax.bar_label(count)
# set x-axis label
ax.set_xlabel('Date')
ax.legend(loc=2)
# set y-axis label
#ax.set_ylabel('Number of Runs',color='red')
ax.set_ylabel('Distance per week',color='red')
# twin object for two different y-axis on the sample plot
ax2=ax.twinx()
# make a plot with different y-axis using second axis object
ax2.plot(dfW['Date'],dfW['Avg Stride Length'],color='blue',marker='o',label='Avg Stride Length')
ax2.set_ylabel('Avg Stride Length',color='blue')
ax2.legend()
plt.show()

# %%
# create figure and axis objects with subplots()
fig,ax = plt.subplots(figsize=(14,6))
# make a barplot
#count = ax.bar(dfW['Date'], dfW['Count'],width=10, color='red',label='Number of Runs')
count = ax.bar(dfW['Date'], dfW['Distance'],width=10, color='red',label='Distance per week')
#ax.bar_label(count)
# set x-axis label
ax.set_xlabel('Date')
ax.legend()
# set y-axis label
#ax.set_ylabel('Number of Runs',color='red')
ax.set_ylabel('Distance per week',color='red')
# twin object for two different y-axis on the sample plot
ax2=ax.twinx()
# make a plot with different y-axis using second axis object
ax2.plot(dfW['Date'],dfW['Avg Run Cadence'],color='blue',marker='o',label='Avg Run Cadence')
ax2.set_ylabel('Cadence',color='blue')
ax2.legend(loc=2)
plt.show()

# %%
df.drop(columns=['isInjured'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-105-a5bdd2cb42f9> in <module>
# ----> 1 df.drop(columns=['isInjured'])
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4161                 weight  1.0     0.8
#    4162         """
# -> 4163         return super().drop(
#    4164             labels=labels,
#    4165             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3885         for axis, labels in axes.items():
#    3886             if labels is not None:
# -> 3887                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3888
#    3889         if inplace:
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    3919                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3920             else:
# -> 3921                 new_axis = axis.drop(labels, errors=errors)
#    3922             result = self.reindex(**{axis_name: new_axis})
#    3923
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    5280         if mask.any():
#    5281             if errors != "ignore":
# -> 5282                 raise KeyError(f"{labels[mask]} not found in axis")
#    5283             indexer = indexer[~mask]
#    5284         return self.delete(indexer)
#
# KeyError: "['isInjured'] not found in axis"

# %%
datebeginInj = "1/7/2021 9:13"
dateInjStart = pd.to_datetime(datebeginInj)
dateInjStart

dateEndInj = "4/20/2021 9:13"
dateInjEnd= pd.to_datetime(dateEndInj)
dateInjEnd
# Out:
# Timestamp('2021-04-20 09:13:00')

# %%
testdfW = df
testdfW.dropna()
# Out:
#                    Date  Distance  Calories  Avg HR  Avg Run Cadence  \
# 805 2019-07-09 14:19:00      2.52     167.0   146.0              148
# 803 2019-07-12 09:29:00      6.04     556.0   166.0              150
# 802 2019-07-16 11:19:00      5.63     518.0   166.0              148
# 801 2019-07-19 09:39:00      4.03     390.0   167.0              150
# 798 2019-07-30 12:02:00      4.81     449.0   167.0              148
# ..                  ...       ...       ...     ...              ...
# 5   2021-11-01 16:33:00      5.31     522.0   170.0              165
# 4   2021-11-03 16:24:00      5.30     511.0   163.0              164
# 2   2021-11-05 15:09:00      4.01     371.0   155.0              163
# 1   2021-11-06 09:12:00      4.03     403.0   157.0              165
# 0   2021-11-07 09:13:00      7.48     744.0   155.0              164
#
#      Avg Pace  Best Pace  Avg Stride Length  Elapsed Time  Avg Speed  \
# 805  7.833333   6.250000               1.40     19.766667   7.659574
# 803  8.716667   3.166667               1.23     52.700000   6.883365
# 802  8.783333   6.750000               1.24     85.483333   6.831120
# 801  9.016667   1.033333               1.19     36.333333   6.654344
# 798  8.700000   5.200000               1.24     51.750000   6.896552
# ..        ...        ...                ...           ...        ...
# 5    7.116667   4.233333               1.38     49.466667   8.430913
# 4    7.116667   6.516667               1.38     40.683333   8.430913
# 2    7.266667   4.266667               1.36     41.383333   8.256881
# 1    7.533333   6.633333               1.29     30.600000   7.964602
# 0    8.116667   6.966667               1.21     69.250000   7.392197
#
#      Best Speed     Month  Count
# 805    9.600000  Jul 2019      1
# 803   18.947368  Jul 2019      1
# 802    8.888889  Jul 2019      1
# 801   58.064516  Jul 2019      1
# 798   11.538462  Jul 2019      1
# ..          ...       ...    ...
# 5     14.173228  Nov 2021      1
# 4      9.207161  Nov 2021      1
# 2     14.062500  Nov 2021      1
# 1      9.045226  Nov 2021      1
# 0      8.612440  Nov 2021      1
#
# [646 rows x 13 columns]

# %%
testdfW['isInjured'] = np.where(((testdfW['Date'] >= dateInjStart) & (testdfW['Date'] <= dateInjEnd)), 'True', 'False')
testdfW.dropna()
testy = testdfW[testdfW['isInjured'] == 'True']
testy 
testdfW
# Out:
#                    Date  Distance  Calories  Avg HR  Avg Run Cadence  \
# 805 2019-07-09 14:19:00      2.52     167.0   146.0              148
# 803 2019-07-12 09:29:00      6.04     556.0   166.0              150
# 802 2019-07-16 11:19:00      5.63     518.0   166.0              148
# 801 2019-07-19 09:39:00      4.03     390.0   167.0              150
# 798 2019-07-30 12:02:00      4.81     449.0   167.0              148
# ..                  ...       ...       ...     ...              ...
# 5   2021-11-01 16:33:00      5.31     522.0   170.0              165
# 4   2021-11-03 16:24:00      5.30     511.0   163.0              164
# 2   2021-11-05 15:09:00      4.01     371.0   155.0              163
# 1   2021-11-06 09:12:00      4.03     403.0   157.0              165
# 0   2021-11-07 09:13:00      7.48     744.0   155.0              164
#
#      Avg Pace  Best Pace  Avg Stride Length  Elapsed Time  Avg Speed  \
# 805  7.833333   6.250000               1.40     19.766667   7.659574
# 803  8.716667   3.166667               1.23     52.700000   6.883365
# 802  8.783333   6.750000               1.24     85.483333   6.831120
# 801  9.016667   1.033333               1.19     36.333333   6.654344
# 798  8.700000   5.200000               1.24     51.750000   6.896552
# ..        ...        ...                ...           ...        ...
# 5    7.116667   4.233333               1.38     49.466667   8.430913
# 4    7.116667   6.516667               1.38     40.683333   8.430913
# 2    7.266667   4.266667               1.36     41.383333   8.256881
# 1    7.533333   6.633333               1.29     30.600000   7.964602
# 0    8.116667   6.966667               1.21     69.250000   7.392197
#
#      Best Speed     Month  Count isInjured
# 805    9.600000  Jul 2019      1     False
# 803   18.947368  Jul 2019      1     False
# 802    8.888889  Jul 2019      1     False
# 801   58.064516  Jul 2019      1     False
# 798   11.538462  Jul 2019      1     False
# ..          ...       ...    ...       ...
# 5     14.173228  Nov 2021      1     False
# 4      9.207161  Nov 2021      1     False
# 2     14.062500  Nov 2021      1     False
# 1      9.045226  Nov 2021      1     False
# 0      8.612440  Nov 2021      1     False
#
# [646 rows x 14 columns]

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 1
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-72-d5aefd861081> in <module>
# ----> 1 if testdfW[1]['Date'] < dateInjStart:
#       2     print("True")
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2900             if self.columns.nlevels > 1:
#    2901                 return self._getitem_multilevel(key)
# -> 2902             indexer = self.columns.get_loc(key)
#    2903             if is_integer(indexer):
#    2904                 indexer = [indexer]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
# -> 2897                 raise KeyError(key) from err
#    2898
#    2899         if tolerance is not None:
#
# KeyError: 1

# %%
testdfW.where(testdfW['isInjured']==True)
# Out:
#     Date  Distance  Calories  Avg HR  Avg Run Cadence  Avg Pace  Best Pace  \
# 805  NaT       NaN       NaN     NaN              NaN       NaN        NaN
# 803  NaT       NaN       NaN     NaN              NaN       NaN        NaN
# 802  NaT       NaN       NaN     NaN              NaN       NaN        NaN
# 798  NaT       NaN       NaN     NaN              NaN       NaN        NaN
# 795  NaT       NaN       NaN     NaN              NaN       NaN        NaN
# ..   ...       ...       ...     ...              ...       ...        ...
# 5    NaT       NaN       NaN     NaN              NaN       NaN        NaN
# 4    NaT       NaN       NaN     NaN              NaN       NaN        NaN
# 2    NaT       NaN       NaN     NaN              NaN       NaN        NaN
# 1    NaT       NaN       NaN     NaN              NaN       NaN        NaN
# 0    NaT       NaN       NaN     NaN              NaN       NaN        NaN
#
#      Avg Stride Length  Elapsed Time  Avg Speed  Best Speed Month  Count  \
# 805                NaN           NaN        NaN         NaN   NaN    NaN
# 803                NaN           NaN        NaN         NaN   NaN    NaN
# 802                NaN           NaN        NaN         NaN   NaN    NaN
# 798                NaN           NaN        NaN         NaN   NaN    NaN
# 795                NaN           NaN        NaN         NaN   NaN    NaN
# ..                 ...           ...        ...         ...   ...    ...
# 5                  NaN           NaN        NaN         NaN   NaN    NaN
# 4                  NaN           NaN        NaN         NaN   NaN    NaN
# 2                  NaN           NaN        NaN         NaN   NaN    NaN
# 1                  NaN           NaN        NaN         NaN   NaN    NaN
# 0                  NaN           NaN        NaN         NaN   NaN    NaN
#
#      isInjured
# 805        NaN
# 803        NaN
# 802        NaN
# 798        NaN
# 795        NaN
# ..         ...
# 5          NaN
# 4          NaN
# 2          NaN
# 1          NaN
# 0          NaN
#
# [520 rows x 14 columns]
